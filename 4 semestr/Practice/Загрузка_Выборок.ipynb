# %%
import random as rd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

# %%
A=scipy.io.loadmat('Level1_Data6.mat')
D=A['D']
print(D)
# Out:
# [[1.49497584 1.50259408 1.50767008 ... 1.49873194 1.47835516 1.47631563]]

# %%
import sympy as sp
import random as rd
import numpy as np
import matplotlib.pyplot as plt
import scipy.io

A=scipy.io.loadmat('QuadMNK_Data16.mat')
X=np.array(A['X'])
Y=A['Y']
print(np.shape(X))

plt.figure(figsize=(17,8))         # косметика графика
for x,y in zip(X,Y):
    plt.scatter(x,y)
#for i in range(1,N+1):
#    CountNow=np.count_nonzero(D<Hpoint[i])-np.count_nonzero(D<Hpoint[i-1])
#    Count.append(CountNow)
#    plt.fill([Hpoint[i-1],Hpoint[i-1],Hpoint[i],Hpoint[i],Hpoint[i-1]],[0,CountNow,CountNow,0,0])
plt.xlabel('x')
plt.ylabel('y')
plt.xlim([Dmin-0.2*(Dmax-Dmin),Dmax+0.2*(Dmax-Dmin)])
plt.title('Выборка для квадратичной регрессии')
plt.grid()
plt.show()
# Out:
# (1, 1000)
